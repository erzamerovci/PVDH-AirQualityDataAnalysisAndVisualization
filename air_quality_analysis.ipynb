# %%
import pandas as pd
import numpy as np

# %%
df_athens = pd.read_csv('athens.csv')
df_athens
# Out:
#                         Date   Latitude  Longitude  \
# 0        2020-05-01 00:00:00  38.150000  23.550000
# 1        2020-05-01 00:00:00  37.850000  23.750000
# 2        2020-05-01 00:00:00  38.150000  23.650000
# 3        2020-05-01 00:00:00  37.850000  23.850000
# 4        2020-05-01 00:00:00  37.850000  23.950000
# ...                      ...        ...        ...
# 1726459  2023-05-29 23:00:00  37.932000  23.713000
# 1726460  2023-05-29 23:00:00  37.901000  23.879000
# 1726461  2023-05-29 23:00:00  37.948063  23.728360
# 1726462  2023-05-29 23:00:00  37.977210  23.783016
# 1726463  2023-05-29 23:00:00  37.978000  23.727000
#
#                                     station_name  Wind-Speed (U)  \
# 0                          Athens CAMS station 0        1.713115
# 1                          Athens CAMS station 9        1.960498
# 2                          Athens CAMS station 1        1.640985
# 3                         Athens CAMS station 10        2.003834
# 4                         Athens CAMS station 11        1.954063
# ...                                          ...             ...
# 1726459                                   SMYRNI        0.240230
# 1726460                                   KOROPI        0.075186
# 1726461                              PANACEA_045             NaN
# 1726462  National Technical University of Athens             NaN
# 1726463                                  ATHINAS        0.209901
#
#          Wind-Speed (V)  Dewpoint Temp  Soil Temp  Total Percipitation  \
# 0             -0.588855      10.046454  17.083554             0.000035
# 1             -0.937417      10.270286  17.909675             0.000037
# 2             -0.556073       9.700422  16.976489             0.000040
# 3             -0.971722      10.159251  17.993456             0.000036
# 4             -0.912335       9.993532  17.957935             0.000036
# ...                 ...            ...        ...                  ...
# 1726459       -1.216293      13.464139  20.926649             0.000809
# 1726460       -1.339309      13.110978  21.116500             0.000581
# 1726461             NaN            NaN        NaN                  NaN
# 1726462             NaN            NaN        NaN                  NaN
# 1726463       -1.259627      13.790172  21.719023             0.000797
#
#          Vegitation (High)  Vegitation (Low)       Temp  Relative Humidity  \
# 0                 1.699026          2.244626  12.948856          82.578812
# 1                 1.743299          1.431182  14.011539          78.352731
# 2                 1.642665          2.172998  12.550690          82.840317
# 3                 1.753648          1.582832  14.261641          76.558915
# 4                 1.706804          1.806660  14.179075          76.140202
# ...                    ...               ...        ...                ...
# 1726459           1.557783          1.392521  16.946201          79.994187
# 1726460           1.663799          2.290440  17.310772          76.371899
# 1726461                NaN               NaN        NaN                NaN
# 1726462                NaN               NaN        NaN                NaN
# 1726463           1.039985          1.013138  17.284556          79.951931
#
#               PM10      PM2.5        NO2        O3     code   id
# 0         8.101824   6.200135   3.479941  76.28401  ACAMS00   45
# 1        10.520411   7.836725  17.563843  74.39110  ACAMS09   54
# 2         8.587352   6.306404   2.892315  74.56569  ACAMS01   46
# 3        10.917974   8.207660  17.196804  67.90412  ACAMS10   55
# 4        11.353168   8.217451  15.817172  67.63471  ACAMS11   56
# ...            ...        ...        ...       ...      ...  ...
# 1726459  19.000000  20.736000  24.000000  62.00000  GR0031A   15
# 1726460  22.000000  12.737628  15.000000  58.00000  GR0120A   21
# 1726461  20.490770  13.595480        NaN       NaN   PAN045   73
# 1726462  14.873333  13.720000        NaN       NaN   NTUA01  101
# 1726463  19.360000  18.053333  27.000000       NaN  GR0027A    9
#
# [1726464 rows x 19 columns]

# %%
df_athens.dtypes
# Out:
# Date                    object
# Latitude               float64
# Longitude              float64
# station_name            object
# Wind-Speed (U)         float64
# Wind-Speed (V)         float64
# Dewpoint Temp          float64
# Soil Temp              float64
# Total Percipitation    float64
# Vegitation (High)      float64
# Vegitation (Low)       float64
# Temp                   float64
# Relative Humidity      float64
# PM10                   float64
# PM2.5                  float64
# NO2                    float64
# O3                     float64
# code                    object
# id                       int64
# dtype: object

# %%
df_athens['Date'] = pd.to_datetime(df_athens['Date'])

# %%
df_athens.columns
# Out:
# Index(['Date', 'Latitude', 'Longitude', 'station_name', 'Wind-Speed (U)',
#        'Wind-Speed (V)', 'Dewpoint Temp', 'Soil Temp', 'Total Percipitation',
#        'Vegitation (High)', 'Vegitation (Low)', 'Temp', 'Relative Humidity',
#        'PM10', 'PM2.5', 'NO2', 'O3', 'code', 'id'],
#       dtype='object')

# %%
len(df_athens.columns)
# Out:
# 19

# %%
df_athens[df_athens.isnull().any(axis=1)].reset_index()
# Out:
#           index                Date   Latitude  Longitude  \
# 0            28 2020-05-01 00:00:00  38.083630  23.700375
# 1            29 2020-05-01 00:00:00  37.978000  23.727000
# 2            32 2020-05-01 00:00:00  37.989967  23.708792
# 3            33 2020-05-01 00:00:00  38.040443  23.833649
# 4            34 2020-05-01 00:00:00  37.982040  23.794780
# ...         ...                 ...        ...        ...
# 176016  1726447 2023-05-29 23:00:00  38.040443  23.833649
# 176017  1726455 2023-05-29 23:00:00  37.989967  23.708792
# 176018  1726461 2023-05-29 23:00:00  37.948063  23.728360
# 176019  1726462 2023-05-29 23:00:00  37.977210  23.783016
# 176020  1726463 2023-05-29 23:00:00  37.978000  23.727000
#
#                                    station_name  Wind-Speed (U)  \
# 0                          Ano Liosia (Perneri)        1.542801
# 1                                       ATHINAS        1.941428
# 2                                ATH-ENVICARE-3        2.009380
# 3                                     ATHENS_01        1.726030
# 4                                     ATHENS_02        1.827617
# ...                                         ...             ...
# 176016                                ATHENS_01        0.289962
# 176017                           ATH-ENVICARE-3        0.176714
# 176018                              PANACEA_045             NaN
# 176019  National Technical University of Athens             NaN
# 176020                                  ATHINAS        0.209901
#
#         Wind-Speed (V)  Dewpoint Temp  Soil Temp  Total Percipitation  \
# 0            -0.602022       9.329610  16.811724             0.000050
# 1            -0.999548      10.683342  18.271925             0.000041
# 2            -1.119707      11.185055  18.745936             0.000041
# 3            -0.735917       9.740093  17.569076             0.000047
# 4            -0.878582      10.030270  17.812905             0.000044
# ...                ...            ...        ...                  ...
# 176016       -1.179780      13.220562  20.343453             0.000985
# 176017       -1.305320      14.187760  22.675439             0.000758
# 176018             NaN            NaN        NaN                  NaN
# 176019             NaN            NaN        NaN                  NaN
# 176020       -1.259627      13.790172  21.719023             0.000797
#
#         Vegitation (High)  Vegitation (Low)       Temp  Relative Humidity  \
# 0                1.680861          2.289204  11.751732          85.142672
# 1                1.056650          1.017622  13.887849          81.121429
# 2                0.450644          0.684208  13.997490          83.183875
# 3                1.597551          1.287751  13.523624          77.993012
# 4                1.471124          0.785802  14.188421          76.102745
# ...                   ...               ...        ...                ...
# 176016           1.569434          1.282711  16.578436          80.566451
# 176017           0.445583          0.680323  17.708009          79.856782
# 176018                NaN               NaN        NaN                NaN
# 176019                NaN               NaN        NaN                NaN
# 176020           1.039985          1.013138  17.284556          79.951931
#
#               PM10       PM2.5        NO2         O3      code   id
# 0        11.838625    9.954234  12.530855  63.666874       NaN   89
# 1       229.000000  131.000000        NaN        NaN   GR0027A    9
# 2       229.000000  131.000000        NaN        NaN  ATHEN023   86
# 3        14.538260   11.451291        NaN        NaN   ATHN001   87
# 4        12.000000   13.000000        NaN        NaN   ATHN002   88
# ...            ...         ...        ...        ...       ...  ...
# 176016   17.787500   16.412500        NaN        NaN   ATHN001   87
# 176017   32.000000   21.538462        NaN        NaN  ATHEN023   86
# 176018   20.490770   13.595480        NaN        NaN    PAN045   73
# 176019   14.873333   13.720000        NaN        NaN    NTUA01  101
# 176020   19.360000   18.053333  27.000000        NaN   GR0027A    9
#
# [176021 rows x 20 columns]

# %%
(df_athens.isnull().sum() / len(df_athens) * 100).sort_values(ascending=False)
# Out:
# O3                     8.576142
# NO2                    8.299797
# code                   1.562500
# Vegitation (High)      0.496564
# Wind-Speed (U)         0.496564
# Wind-Speed (V)         0.496564
# Dewpoint Temp          0.496564
# Soil Temp              0.496564
# Total Percipitation    0.496564
# Vegitation (Low)       0.496564
# Relative Humidity      0.496564
# Temp                   0.438179
# PM2.5                  0.000000
# Date                   0.000000
# PM10                   0.000000
# Latitude               0.000000
# station_name           0.000000
# Longitude              0.000000
# id                     0.000000
# dtype: float64

# %%
df_athens["station_name"].value_counts()
# Out:
# station_name
# Athens CAMS station 0    26976
# Athens CAMS station 9    26976
# ATHENS_02                26976
# PANACEA_001              26976
# PANACEA_000              26976
#                          ...
# KOROPI                   26976
# PERISTERI                26976
# Ano Liosia (Perneri)     26976
# ATHINAS                  26976
# PANACEA_006              26976
# Name: count, Length: 64, dtype: int64

# %%
df_athens["code"].isna().sum()
# Out:
# 26976

# %%
df_athens['code'] = df_athens['code'].fillna('ANO001')

# %%
(df_athens.isnull().sum() / len(df_athens) * 100).sort_values(ascending=False)
# Out:
# O3                     8.576142
# NO2                    8.299797
# Vegitation (High)      0.496564
# Wind-Speed (U)         0.496564
# Wind-Speed (V)         0.496564
# Dewpoint Temp          0.496564
# Soil Temp              0.496564
# Total Percipitation    0.496564
# Vegitation (Low)       0.496564
# Relative Humidity      0.496564
# Temp                   0.438179
# PM2.5                  0.000000
# code                   0.000000
# Date                   0.000000
# PM10                   0.000000
# Latitude               0.000000
# station_name           0.000000
# Longitude              0.000000
# id                     0.000000
# dtype: float64

# %%
cols = [
    "Vegitation (High)", "Wind-Speed (U)", "Wind-Speed (V)", 
    "Dewpoint Temp", "Soil Temp", "Total Percipitation", 
    "Vegitation (Low)", "Relative Humidity"
]

# %%
same_missing_pattern = df_athens[cols].isna().eq(df_athens[cols[0]].isna(), axis=0).all().all()

print("Do all these columns have the same missing pattern?", same_missing_pattern)
# Out:
# Do all these columns have the same missing pattern? True

# %%
df_athens.iloc[[463892]]
# Out:
#              Date   Latitude  Longitude station_name  Wind-Speed (U)  \
# 463892 2021-02-27  38.013317  23.647491  PANACEA_014             NaN
#
#         Wind-Speed (V)  Dewpoint Temp  Soil Temp  Total Percipitation  \
# 463892             NaN            NaN        NaN                  NaN
#
#         Vegitation (High)  Vegitation (Low)      Temp  Relative Humidity  \
# 463892                NaN               NaN  6.031614                NaN
#
#              PM10     PM2.5   NO2    O3    code  id
# 463892  43.575862  22.39247  36.0  32.0  PAN014  99

# %%
cols_to_fill = [
    "Vegitation (High)", "Wind-Speed (U)", "Wind-Speed (V)", 
    "Dewpoint Temp", "Soil Temp", "Total Percipitation", 
    "Vegitation (Low)", "Relative Humidity"
]

original_index = df_athens.index
original_order = df_athens.copy()

df_athens = df_athens.sort_values(['station_name', 'Date'])
df_athens[cols_to_fill] = df_athens.groupby('station_name')[cols_to_fill].fillna(method='ffill')
df_athens = df_athens.reindex(original_index)
# Out:
# C:\Users\forte\AppData\Local\Temp\ipykernel_4868\3800076259.py:11: FutureWarning: DataFrameGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use DataFrame.fillna instead
#   df_athens[cols_to_fill] = df_athens.groupby('station_name')[cols_to_fill].fillna(method='ffill')
# C:\Users\forte\AppData\Local\Temp\ipykernel_4868\3800076259.py:11: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_athens[cols_to_fill] = df_athens.groupby('station_name')[cols_to_fill].fillna(method='ffill')

# %%
df_athens.iloc[[463850]]
# Out:
#                       Date   Latitude  Longitude station_name  Wind-Speed (U)  \
# 463850 2021-02-26 23:00:00  38.013317  23.647491  PANACEA_014        0.702335
#
#         Wind-Speed (V)  Dewpoint Temp  Soil Temp  Total Percipitation  \
# 463850       -1.628909       5.989872  11.108342         9.936383e-07
#
#         Vegitation (High)  Vegitation (Low)      Temp  Relative Humidity  \
# 463850           1.507902          1.124172  6.754565          94.904331
#
#          PM10      PM2.5   NO2    O3    code  id
# 463850  56.77  22.428232  51.0  25.0  PAN014  99

# %%
(df_athens.isnull().sum() / len(df_athens) * 100).sort_values(ascending=False)
# Out:
# O3                     8.576142
# NO2                    8.299797
# Temp                   0.438179
# Date                   0.000000
# Vegitation (Low)       0.000000
# code                   0.000000
# PM2.5                  0.000000
# PM10                   0.000000
# Relative Humidity      0.000000
# Vegitation (High)      0.000000
# Latitude               0.000000
# Total Percipitation    0.000000
# Soil Temp              0.000000
# Dewpoint Temp          0.000000
# Wind-Speed (V)         0.000000
# Wind-Speed (U)         0.000000
# station_name           0.000000
# Longitude              0.000000
# id                     0.000000
# dtype: float64

# %%
original_index = df_athens.index

df_athens_sorted = df_athens.sort_values(['station_name', 'Date']).copy()

df_athens_sorted['Temp'] = (
    df_athens_sorted
    .groupby('station_name')['Temp']
    .transform(lambda x: x.interpolate(method='linear', limit_direction='both'))
)

df_athens = df_athens_sorted.reindex(original_index)

# %%
(df_athens.isnull().sum() / len(df_athens) * 100).sort_values(ascending=False)
# Out:
# O3                     8.576142
# NO2                    8.299797
# Date                   0.000000
# Vegitation (Low)       0.000000
# code                   0.000000
# PM2.5                  0.000000
# PM10                   0.000000
# Relative Humidity      0.000000
# Temp                   0.000000
# Vegitation (High)      0.000000
# Latitude               0.000000
# Total Percipitation    0.000000
# Soil Temp              0.000000
# Dewpoint Temp          0.000000
# Wind-Speed (V)         0.000000
# Wind-Speed (U)         0.000000
# station_name           0.000000
# Longitude              0.000000
# id                     0.000000
# dtype: float64

# %%
stations_under_10300_O3 = (
    df_athens[df_athens['O3'].isna()]
    ['station_name']
    .value_counts()
    .loc[lambda x: x < 10300]
    .index
)

stations_under_10300_NO2 = (
    df_athens[df_athens['NO2'].isna()]
    ['station_name']
    .value_counts()
    .loc[lambda x: x < 10300]
    .index
)

df_athens = df_athens.sort_values(['station_name', 'Date'])
df_athens.loc[
    df_athens['station_name'].isin(stations_under_10300_O3), 'O3'
] = (
    df_athens[df_athens['station_name'].isin(stations_under_10300_O3)]
    .groupby('station_name')['O3']
    .fillna(method='ffill')
)

df_athens.loc[
    df_athens['station_name'].isin(stations_under_10300_NO2), 'NO2'
] = (
    df_athens[df_athens['station_name'].isin(stations_under_10300_NO2)]
    .groupby('station_name')['NO2']
    .fillna(method='ffill')
)

df_athens = df_athens.reindex(original_index)
# Out:
# C:\Users\forte\AppData\Local\Temp\ipykernel_4868\2195111783.py:23: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   .fillna(method='ffill')
# C:\Users\forte\AppData\Local\Temp\ipykernel_4868\2195111783.py:23: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   .fillna(method='ffill')
# C:\Users\forte\AppData\Local\Temp\ipykernel_4868\2195111783.py:31: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   .fillna(method='ffill')
# C:\Users\forte\AppData\Local\Temp\ipykernel_4868\2195111783.py:31: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   .fillna(method='ffill')

# %%
(df_athens.isnull().sum() / len(df_athens) * 100).sort_values(ascending=False)
# Out:
# O3                     7.812674
# NO2                    7.812674
# Date                   0.000000
# Vegitation (Low)       0.000000
# code                   0.000000
# PM2.5                  0.000000
# PM10                   0.000000
# Relative Humidity      0.000000
# Temp                   0.000000
# Vegitation (High)      0.000000
# Latitude               0.000000
# Total Percipitation    0.000000
# Soil Temp              0.000000
# Dewpoint Temp          0.000000
# Wind-Speed (V)         0.000000
# Wind-Speed (U)         0.000000
# station_name           0.000000
# Longitude              0.000000
# id                     0.000000
# dtype: float64

# %%
df_athens[df_athens['O3'].isna()]["station_name"].value_counts()
# Out:
# station_name
# ATH-ENVICARE-3                     26976
# ATHENS_01                          26976
# ATHENS_02                          26976
# CleanAir in Greece - Thiseio II    26976
# CleanAir in Greece - Thiseio       26976
# ATHINAS                                3
# Name: count, dtype: int64

# %%
df_athens.loc[df_athens['station_name'] == 'ATHINAS', 'NO2'] = (
    df_athens.loc[df_athens['station_name'] == 'ATHINAS', 'NO2'].fillna(35.0)
)
df_athens.loc[df_athens['station_name'] == 'ATHINAS', 'O3'] = (
    df_athens.loc[df_athens['station_name'] == 'ATHINAS', 'O3'].fillna(2.0)
)

# %%
df_athens[df_athens['O3'].isna()]["station_name"].value_counts()
# Out:
# station_name
# ATH-ENVICARE-3                     26976
# ATHENS_01                          26976
# ATHENS_02                          26976
# CleanAir in Greece - Thiseio II    26976
# CleanAir in Greece - Thiseio       26976
# Name: count, dtype: int64

# %%
df_pivot = df_athens.pivot_table(
    index='Date',
    columns='station_name',
    values='PM2.5'
)
df_pivot
# Out:
# station_name         ARISTOTELOUS  ATH-ENVICARE-0  ATH-ENVICARE-2  \
# Date
# 2020-05-01 00:00:00         131.0      131.000000       10.683514
# 2020-05-01 01:00:00         140.0      140.000000       10.468672
# 2020-05-01 02:00:00         131.0      131.000000       10.439608
# 2020-05-01 03:00:00         109.0      109.000000       10.487819
# 2020-05-01 04:00:00          59.0       59.000000       10.025481
# ...                           ...             ...             ...
# 2023-05-29 19:00:00          17.0       22.582609       14.937931
# 2023-05-29 20:00:00          16.0       18.234483       14.014286
# 2023-05-29 21:00:00          15.0       15.079310       16.960714
# 2023-05-29 22:00:00          15.0       17.544828       18.841379
# 2023-05-29 23:00:00          16.0       18.053333       22.665517
#
# station_name         ATH-ENVICARE-3  ATHENS_01  ATHENS_02     ATHINAS  \
# Date
# 2020-05-01 00:00:00      131.000000  11.451291  13.000000  131.000000
# 2020-05-01 01:00:00      140.000000  10.161569  10.000000  140.000000
# 2020-05-01 02:00:00      131.000000   9.567772  15.000000  131.000000
# 2020-05-01 03:00:00      109.000000   9.537518  11.000000  109.000000
# 2020-05-01 04:00:00       59.000000   9.273329  12.000000   59.000000
# ...                             ...        ...        ...         ...
# 2023-05-29 19:00:00       23.609091  21.810000  12.414286   22.582609
# 2023-05-29 20:00:00       23.120000  21.681818  24.200000   18.234483
# 2023-05-29 21:00:00       28.909091  14.810000  21.590000   15.079310
# 2023-05-29 22:00:00       19.833333  14.290000  14.113793   17.544828
# 2023-05-29 23:00:00       21.538462  16.412500  13.720000   18.053333
#
# station_name         Ano Liosia (Perneri)  Athens CAMS station 0  \
# Date
# 2020-05-01 00:00:00              9.954234               6.200135
# 2020-05-01 01:00:00             10.004467               6.743588
# 2020-05-01 02:00:00              9.706072               5.907382
# 2020-05-01 03:00:00              9.470734               6.022633
# 2020-05-01 04:00:00              9.136471               5.962640
# ...                                   ...                    ...
# 2023-05-29 19:00:00             10.733333              10.272034
# 2023-05-29 20:00:00             20.988889               9.631711
# 2023-05-29 21:00:00             16.290000               9.266436
# 2023-05-29 22:00:00             15.190000               8.220789
# 2023-05-29 23:00:00             12.277778               8.051229
#
# station_name         Athens CAMS station 1  ...  PANACEA_AirPaP_001  \
# Date                                        ...
# 2020-05-01 00:00:00               6.306404  ...           11.451291
# 2020-05-01 01:00:00               6.821030  ...           10.161569
# 2020-05-01 02:00:00               6.345460  ...            9.567772
# 2020-05-01 03:00:00               6.197413  ...            9.537518
# 2020-05-01 04:00:00               5.968396  ...            9.273329
# ...                                    ...  ...                 ...
# 2023-05-29 19:00:00               9.316439  ...           10.558621
# 2023-05-29 20:00:00               9.220932  ...           11.020000
# 2023-05-29 21:00:00               9.783000  ...           11.765517
# 2023-05-29 22:00:00               9.035696  ...           11.973333
# 2023-05-29 23:00:00               7.414128  ...           13.833333
#
# station_name         PANACEA_AirPaP_002  PANACEA_AirPaP_006  \
# Date
# 2020-05-01 00:00:00          131.000000            9.493142
# 2020-05-01 01:00:00          140.000000           11.157607
# 2020-05-01 02:00:00          131.000000           11.452366
# 2020-05-01 03:00:00          109.000000           10.987174
# 2020-05-01 04:00:00           59.000000           10.538656
# ...                                 ...                 ...
# 2023-05-29 19:00:00           16.775000           16.103846
# 2023-05-29 20:00:00           16.880000           15.554545
# 2023-05-29 21:00:00           19.888889           16.118519
# 2023-05-29 22:00:00           17.240000           16.942857
# 2023-05-29 23:00:00           19.320000           16.265000
#
# station_name         PANACEA_AirPaP_008  PARASKEVI  PERISTERI    PPCITY12  \
# Date
# 2020-05-01 00:00:00            9.493142       13.0   9.954234  131.000000
# 2020-05-01 01:00:00           11.157607       10.0  10.004467  140.000000
# 2020-05-01 02:00:00           11.452366       15.0   9.706072  131.000000
# 2020-05-01 03:00:00           10.987174       11.0   9.470734  109.000000
# 2020-05-01 04:00:00           10.538656       12.0   9.136471   59.000000
# ...                                 ...        ...        ...         ...
# 2023-05-29 19:00:00           25.614815        8.0  16.607692   11.823333
# 2023-05-29 20:00:00           29.668966        8.0  19.925926   12.663333
# 2023-05-29 21:00:00           21.760714        9.0  18.713793   13.036667
# 2023-05-29 22:00:00           21.255556        9.0  16.844828   11.580000
# 2023-05-29 23:00:00           20.736000       11.0  18.900000   12.856667
#
# station_name           PPCITY21     SMYRNI  THRAKOMAKEDONES
# Date
# 2020-05-01 00:00:00  131.000000  10.469307             15.0
# 2020-05-01 01:00:00  140.000000  11.987478             11.0
# 2020-05-01 02:00:00  131.000000  12.428730             20.0
# 2020-05-01 03:00:00  109.000000  12.986314              8.0
# 2020-05-01 04:00:00   59.000000  12.205142              8.0
# ...                         ...        ...              ...
# 2023-05-29 19:00:00   23.275000  25.614815             10.0
# 2023-05-29 20:00:00   23.924138  29.668966             14.0
# 2023-05-29 21:00:00   17.968966  21.760714             12.0
# 2023-05-29 22:00:00   12.758621  21.255556             18.0
# 2023-05-29 23:00:00   12.918182  20.736000              7.0
#
# [26976 rows x 64 columns]

# %%
corr = df_pivot.corr()
corr.index.name = None
corr
# Out:
# station_name     ARISTOTELOUS  ATH-ENVICARE-0  ATH-ENVICARE-2  ATH-ENVICARE-3  \
# ARISTOTELOUS         1.000000        0.393787        0.507643        0.679509
# ATH-ENVICARE-0       0.393787        1.000000        0.358587        0.398883
# ATH-ENVICARE-2       0.507643        0.358587        1.000000        0.782763
# ATH-ENVICARE-3       0.679509        0.398883        0.782763        1.000000
# ATHENS_01            0.423815        0.308364        0.834086        0.672611
# ...                       ...             ...             ...             ...
# PERISTERI            0.516159        0.330928        0.867180        0.839879
# PPCITY12             0.762257        0.391520        0.580238        0.756113
# PPCITY21             0.761672        0.463920        0.677304        0.826243
# SMYRNI               0.594799        0.407982        0.780343        0.829673
# THRAKOMAKEDONES      0.268561        0.099013        0.179808        0.180029
#
# station_name     ATHENS_01  ATHENS_02   ATHINAS  Ano Liosia (Perneri)  \
# ARISTOTELOUS      0.423815   0.337891  0.393787              0.425501
# ATH-ENVICARE-0    0.308364   0.271592  1.000000              0.307701
# ATH-ENVICARE-2    0.834086   0.577095  0.358587              0.759535
# ATH-ENVICARE-3    0.672611   0.488583  0.398883              0.650640
# ATHENS_01         1.000000   0.664393  0.308364              0.758285
# ...                    ...        ...       ...                   ...
# PERISTERI         0.767891   0.526113  0.330928              0.762548
# PPCITY12          0.545681   0.462253  0.391520              0.524610
# PPCITY21          0.628066   0.536739  0.463920              0.604946
# SMYRNI            0.689230   0.499660  0.407982              0.649278
# THRAKOMAKEDONES   0.221958   0.300579  0.099013              0.247127
#
# station_name     Athens CAMS station 0  Athens CAMS station 1  ...  \
# ARISTOTELOUS                  0.250694               0.256402  ...
# ATH-ENVICARE-0                0.145011               0.148196  ...
# ATH-ENVICARE-2                0.268510               0.287352  ...
# ATH-ENVICARE-3                0.245169               0.257100  ...
# ATHENS_01                     0.351952               0.374458  ...
# ...                                ...                    ...  ...
# PERISTERI                     0.284339               0.298833  ...
# PPCITY12                      0.291994               0.301629  ...
# PPCITY21                      0.334073               0.347401  ...
# SMYRNI                        0.310213               0.322374  ...
# THRAKOMAKEDONES               0.388156               0.402091  ...
#
# station_name     PANACEA_AirPaP_001  PANACEA_AirPaP_002  PANACEA_AirPaP_006  \
# ARISTOTELOUS               0.426783            0.646124            0.549174
# ATH-ENVICARE-0             0.308223            0.363194            0.354980
# ATH-ENVICARE-2             0.844881            0.653871            0.801744
# ATH-ENVICARE-3             0.671885            0.720622            0.862421
# ATHENS_01                  0.985026            0.697782            0.723187
# ...                             ...                 ...                 ...
# PERISTERI                  0.765916            0.616538            0.846801
# PPCITY12                   0.547605            0.835147            0.617387
# PPCITY21                   0.628563            0.807833            0.723119
# SMYRNI                     0.692522            0.587015            0.872031
# THRAKOMAKEDONES            0.217694            0.267927            0.190999
#
# station_name     PANACEA_AirPaP_008  PARASKEVI  PERISTERI  PPCITY12  PPCITY21  \
# ARISTOTELOUS               0.596985   0.346003   0.516159  0.762257  0.761672
# ATH-ENVICARE-0             0.407830   0.132280   0.330928  0.391520  0.463920
# ATH-ENVICARE-2             0.778565   0.222183   0.867180  0.580238  0.677304
# ATH-ENVICARE-3             0.830005   0.236129   0.839879  0.756113  0.826243
# ATHENS_01                  0.687281   0.281230   0.767891  0.545681  0.628066
# ...                             ...        ...        ...       ...       ...
# PERISTERI                  0.778882   0.219037   1.000000  0.575392  0.665568
# PPCITY12                   0.622410   0.275575   0.575392  1.000000  0.879847
# PPCITY21                   0.776989   0.296794   0.665568  0.879847  1.000000
# SMYRNI                     0.997924   0.236750   0.779423  0.617798  0.774811
# THRAKOMAKEDONES            0.170997   0.478560   0.181975  0.218716  0.239897
#
# station_name       SMYRNI  THRAKOMAKEDONES
# ARISTOTELOUS     0.594799         0.268561
# ATH-ENVICARE-0   0.407982         0.099013
# ATH-ENVICARE-2   0.780343         0.179808
# ATH-ENVICARE-3   0.829673         0.180029
# ATHENS_01        0.689230         0.221958
# ...                   ...              ...
# PERISTERI        0.779423         0.181975
# PPCITY12         0.617798         0.218716
# PPCITY21         0.774811         0.239897
# SMYRNI           1.000000         0.170421
# THRAKOMAKEDONES  0.170421         1.000000
#
# [64 rows x 64 columns]

# %%
results = []

corr_matrix = corr.copy()

for column in corr_matrix.columns:
    top_2 = corr_matrix[column].nlargest(2)
    second_corr = top_2.iloc[1]
    second_station = top_2.index[1]
    
    results.append({
        'Station': column,
        'Second_Most_Correlated_With': second_station,
        'Correlation_Value': second_corr,
        'Correlation_Percentage': f"{second_corr*100:.1f}%"
    })

results_df = pd.DataFrame(results)
results_df
# Out:
#             Station   Second_Most_Correlated_With  Correlation_Value  \
# 0      ARISTOTELOUS                      PPCITY12           0.762257
# 1    ATH-ENVICARE-0                       ATHINAS           1.000000
# 2    ATH-ENVICARE-2                       MAROUSI           0.873653
# 3    ATH-ENVICARE-3                   PANACEA_029           0.897801
# 4         ATHENS_01            PANACEA_AirPaP_001           0.985026
# ..              ...                           ...                ...
# 59        PERISTERI                   PANACEA_019           0.883139
# 60         PPCITY12                      PPCITY21           0.879847
# 61         PPCITY21  CleanAir in Greece - Thiseio           0.930175
# 62           SMYRNI            PANACEA_AirPaP_008           0.997924
# 63  THRAKOMAKEDONES                   PANACEA_032           0.663706
#
#    Correlation_Percentage
# 0                   76.2%
# 1                  100.0%
# 2                   87.4%
# 3                   89.8%
# 4                   98.5%
# ..                    ...
# 59                  88.3%
# 60                  88.0%
# 61                  93.0%
# 62                  99.8%
# 63                  66.4%
#
# [64 rows x 4 columns]

# %%
results_df[results_df["Station"] == "ATHENS_01"]
# Out:
#      Station Second_Most_Correlated_With  Correlation_Value  \
# 4  ATHENS_01          PANACEA_AirPaP_001           0.985026
#
#   Correlation_Percentage
# 4                  98.5%

# %%
results_df[results_df["Station"] == "ATHENS_02"]
# Out:
#      Station              Second_Most_Correlated_With  Correlation_Value  \
# 5  ATHENS_02  National Technical University of Athens           0.880073
#
#   Correlation_Percentage
# 5                  88.0%

# %%
results_df[results_df["Station"] == "ATH-ENVICARE-3"]
# Out:
#           Station Second_Most_Correlated_With  Correlation_Value  \
# 3  ATH-ENVICARE-3                 PANACEA_029           0.897801
#
#   Correlation_Percentage
# 3                  89.8%

# %%
station_mapping = {
    'ATHENS_01': 'PANACEA_AirPaP_001', 
    'ATHENS_02': 'National Technical University of Athens',
    'ATH-ENVICARE-3': 'PANACEA_029',
    'CleanAir in Greece - Thiseio': 'PPCITY21',
    'CleanAir in Greece - Thiseio II': 'PPCITY21',
}

cols_to_copy = ["O3", "NO2"]

for target, source in station_mapping.items():
    for col in cols_to_copy:
        df_athens.loc[df_athens["station_name"] == target, col] = (
            df_athens.loc[df_athens["station_name"] == source, col].values
        )

# %%
df_athens
# Out:
#                        Date   Latitude  Longitude  \
# 0       2020-05-01 00:00:00  38.150000  23.550000
# 1       2020-05-01 00:00:00  37.850000  23.750000
# 2       2020-05-01 00:00:00  38.150000  23.650000
# 3       2020-05-01 00:00:00  37.850000  23.850000
# 4       2020-05-01 00:00:00  37.850000  23.950000
# ...                     ...        ...        ...
# 1726459 2023-05-29 23:00:00  37.932000  23.713000
# 1726460 2023-05-29 23:00:00  37.901000  23.879000
# 1726461 2023-05-29 23:00:00  37.948063  23.728360
# 1726462 2023-05-29 23:00:00  37.977210  23.783016
# 1726463 2023-05-29 23:00:00  37.978000  23.727000
#
#                                     station_name  Wind-Speed (U)  \
# 0                          Athens CAMS station 0        1.713115
# 1                          Athens CAMS station 9        1.960498
# 2                          Athens CAMS station 1        1.640985
# 3                         Athens CAMS station 10        2.003834
# 4                         Athens CAMS station 11        1.954063
# ...                                          ...             ...
# 1726459                                   SMYRNI        0.240230
# 1726460                                   KOROPI        0.075186
# 1726461                              PANACEA_045       -0.012447
# 1726462  National Technical University of Athens       -0.491393
# 1726463                                  ATHINAS        0.209901
#
#          Wind-Speed (V)  Dewpoint Temp  Soil Temp  Total Percipitation  \
# 0             -0.588855      10.046454  17.083554             0.000035
# 1             -0.937417      10.270286  17.909675             0.000037
# 2             -0.556073       9.700422  16.976489             0.000040
# 3             -0.971722      10.159251  17.993456             0.000036
# 4             -0.912335       9.993532  17.957935             0.000036
# ...                 ...            ...        ...                  ...
# 1726459       -1.216293      13.464139  20.926649             0.000809
# 1726460       -1.339309      13.110978  21.116500             0.000581
# 1726461       -4.024046       0.817448  16.663882             0.000117
# 1726462       -3.956621      12.422827  20.905300             0.000786
# 1726463       -1.259627      13.790172  21.719023             0.000797
#
#          Vegitation (High)  Vegitation (Low)       Temp  Relative Humidity  \
# 0                 1.699026          2.244626  12.948856          82.578812
# 1                 1.743299          1.431182  14.011539          78.352731
# 2                 1.642665          2.172998  12.550690          82.840317
# 3                 1.753648          1.582832  14.261641          76.558915
# 4                 1.706804          1.806660  14.179075          76.140202
# ...                    ...               ...        ...                ...
# 1726459           1.557783          1.392521  16.946201          79.994187
# 1726460           1.663799          2.290440  17.310772          76.371899
# 1726461           1.462879          1.247304  17.860900          31.921052
# 1726462           1.469335          0.926387  22.035118          54.449878
# 1726463           1.039985          1.013138  17.284556          79.951931
#
#               PM10      PM2.5        NO2         O3     code   id
# 0         8.101824   6.200135   3.479941   76.28401  ACAMS00   45
# 1        10.520411   7.836725  17.563843   74.39110  ACAMS09   54
# 2         8.587352   6.306404   2.892315   74.56569  ACAMS01   46
# 3        10.917974   8.207660  17.196804   67.90412  ACAMS10   55
# 4        11.353168   8.217451  15.817172   67.63471  ACAMS11   56
# ...            ...        ...        ...        ...      ...  ...
# 1726459  19.000000  20.736000  24.000000   62.00000  GR0031A   15
# 1726460  22.000000  12.737628  15.000000   58.00000  GR0120A   21
# 1726461  20.490770  13.595480   9.606083  100.65001   PAN045   73
# 1726462  14.873333  13.720000   5.000000   99.00000   NTUA01  101
# 1726463  19.360000  18.053333  27.000000    9.00000  GR0027A    9
#
# [1726464 rows x 19 columns]

# %%
(df_athens.isnull().sum() / len(df_athens) * 100).sort_values(ascending=False)
# Out:
# Date                   0.0
# Vegitation (Low)       0.0
# code                   0.0
# O3                     0.0
# NO2                    0.0
# PM2.5                  0.0
# PM10                   0.0
# Relative Humidity      0.0
# Temp                   0.0
# Vegitation (High)      0.0
# Latitude               0.0
# Total Percipitation    0.0
# Soil Temp              0.0
# Dewpoint Temp          0.0
# Wind-Speed (V)         0.0
# Wind-Speed (U)         0.0
# station_name           0.0
# Longitude              0.0
# id                     0.0
# dtype: float64

# %%
df_athens['Wind_Speed'] = np.sqrt(df_athens['Wind-Speed (U)']**2 + df_athens['Wind-Speed (V)']**2)
df_athens
# Out:
#                        Date   Latitude  Longitude  \
# 0       2020-05-01 00:00:00  38.150000  23.550000
# 1       2020-05-01 00:00:00  37.850000  23.750000
# 2       2020-05-01 00:00:00  38.150000  23.650000
# 3       2020-05-01 00:00:00  37.850000  23.850000
# 4       2020-05-01 00:00:00  37.850000  23.950000
# ...                     ...        ...        ...
# 1726459 2023-05-29 23:00:00  37.932000  23.713000
# 1726460 2023-05-29 23:00:00  37.901000  23.879000
# 1726461 2023-05-29 23:00:00  37.948063  23.728360
# 1726462 2023-05-29 23:00:00  37.977210  23.783016
# 1726463 2023-05-29 23:00:00  37.978000  23.727000
#
#                                     station_name  Wind-Speed (U)  \
# 0                          Athens CAMS station 0        1.713115
# 1                          Athens CAMS station 9        1.960498
# 2                          Athens CAMS station 1        1.640985
# 3                         Athens CAMS station 10        2.003834
# 4                         Athens CAMS station 11        1.954063
# ...                                          ...             ...
# 1726459                                   SMYRNI        0.240230
# 1726460                                   KOROPI        0.075186
# 1726461                              PANACEA_045       -0.012447
# 1726462  National Technical University of Athens       -0.491393
# 1726463                                  ATHINAS        0.209901
#
#          Wind-Speed (V)  Dewpoint Temp  Soil Temp  Total Percipitation  \
# 0             -0.588855      10.046454  17.083554             0.000035
# 1             -0.937417      10.270286  17.909675             0.000037
# 2             -0.556073       9.700422  16.976489             0.000040
# 3             -0.971722      10.159251  17.993456             0.000036
# 4             -0.912335       9.993532  17.957935             0.000036
# ...                 ...            ...        ...                  ...
# 1726459       -1.216293      13.464139  20.926649             0.000809
# 1726460       -1.339309      13.110978  21.116500             0.000581
# 1726461       -4.024046       0.817448  16.663882             0.000117
# 1726462       -3.956621      12.422827  20.905300             0.000786
# 1726463       -1.259627      13.790172  21.719023             0.000797
#
#          Vegitation (High)  Vegitation (Low)       Temp  Relative Humidity  \
# 0                 1.699026          2.244626  12.948856          82.578812
# 1                 1.743299          1.431182  14.011539          78.352731
# 2                 1.642665          2.172998  12.550690          82.840317
# 3                 1.753648          1.582832  14.261641          76.558915
# 4                 1.706804          1.806660  14.179075          76.140202
# ...                    ...               ...        ...                ...
# 1726459           1.557783          1.392521  16.946201          79.994187
# 1726460           1.663799          2.290440  17.310772          76.371899
# 1726461           1.462879          1.247304  17.860900          31.921052
# 1726462           1.469335          0.926387  22.035118          54.449878
# 1726463           1.039985          1.013138  17.284556          79.951931
#
#               PM10      PM2.5        NO2         O3     code   id  Wind_Speed
# 0         8.101824   6.200135   3.479941   76.28401  ACAMS00   45    1.811495
# 1        10.520411   7.836725  17.563843   74.39110  ACAMS09   54    2.173086
# 2         8.587352   6.306404   2.892315   74.56569  ACAMS01   46    1.732642
# 3        10.917974   8.207660  17.196804   67.90412  ACAMS10   55    2.227015
# 4        11.353168   8.217451  15.817172   67.63471  ACAMS11   56    2.156552
# ...            ...        ...        ...        ...      ...  ...         ...
# 1726459  19.000000  20.736000  24.000000   62.00000  GR0031A   15    1.239790
# 1726460  22.000000  12.737628  15.000000   58.00000  GR0120A   21    1.341418
# 1726461  20.490770  13.595480   9.606083  100.65001   PAN045   73    4.024065
# 1726462  14.873333  13.720000   5.000000   99.00000   NTUA01  101    3.987019
# 1726463  19.360000  18.053333  27.000000    9.00000  GR0027A    9    1.276996
#
# [1726464 rows x 20 columns]

# %%
df_athens['Point'] = df_athens.apply(lambda row: (row['Latitude'], row['Longitude']), axis=1)

df_athens = df_athens.drop(columns=['Latitude', 'Longitude'])

df_athens
# Out:
#                        Date                             station_name  \
# 0       2020-05-01 00:00:00                    Athens CAMS station 0
# 1       2020-05-01 00:00:00                    Athens CAMS station 9
# 2       2020-05-01 00:00:00                    Athens CAMS station 1
# 3       2020-05-01 00:00:00                   Athens CAMS station 10
# 4       2020-05-01 00:00:00                   Athens CAMS station 11
# ...                     ...                                      ...
# 1726459 2023-05-29 23:00:00                                   SMYRNI
# 1726460 2023-05-29 23:00:00                                   KOROPI
# 1726461 2023-05-29 23:00:00                              PANACEA_045
# 1726462 2023-05-29 23:00:00  National Technical University of Athens
# 1726463 2023-05-29 23:00:00                                  ATHINAS
#
#          Wind-Speed (U)  Wind-Speed (V)  Dewpoint Temp  Soil Temp  \
# 0              1.713115       -0.588855      10.046454  17.083554
# 1              1.960498       -0.937417      10.270286  17.909675
# 2              1.640985       -0.556073       9.700422  16.976489
# 3              2.003834       -0.971722      10.159251  17.993456
# 4              1.954063       -0.912335       9.993532  17.957935
# ...                 ...             ...            ...        ...
# 1726459        0.240230       -1.216293      13.464139  20.926649
# 1726460        0.075186       -1.339309      13.110978  21.116500
# 1726461       -0.012447       -4.024046       0.817448  16.663882
# 1726462       -0.491393       -3.956621      12.422827  20.905300
# 1726463        0.209901       -1.259627      13.790172  21.719023
#
#          Total Percipitation  Vegitation (High)  Vegitation (Low)       Temp  \
# 0                   0.000035           1.699026          2.244626  12.948856
# 1                   0.000037           1.743299          1.431182  14.011539
# 2                   0.000040           1.642665          2.172998  12.550690
# 3                   0.000036           1.753648          1.582832  14.261641
# 4                   0.000036           1.706804          1.806660  14.179075
# ...                      ...                ...               ...        ...
# 1726459             0.000809           1.557783          1.392521  16.946201
# 1726460             0.000581           1.663799          2.290440  17.310772
# 1726461             0.000117           1.462879          1.247304  17.860900
# 1726462             0.000786           1.469335          0.926387  22.035118
# 1726463             0.000797           1.039985          1.013138  17.284556
#
#          Relative Humidity       PM10      PM2.5        NO2         O3  \
# 0                82.578812   8.101824   6.200135   3.479941   76.28401
# 1                78.352731  10.520411   7.836725  17.563843   74.39110
# 2                82.840317   8.587352   6.306404   2.892315   74.56569
# 3                76.558915  10.917974   8.207660  17.196804   67.90412
# 4                76.140202  11.353168   8.217451  15.817172   67.63471
# ...                    ...        ...        ...        ...        ...
# 1726459          79.994187  19.000000  20.736000  24.000000   62.00000
# 1726460          76.371899  22.000000  12.737628  15.000000   58.00000
# 1726461          31.921052  20.490770  13.595480   9.606083  100.65001
# 1726462          54.449878  14.873333  13.720000   5.000000   99.00000
# 1726463          79.951931  19.360000  18.053333  27.000000    9.00000
#
#             code   id  Wind_Speed                  Point
# 0        ACAMS00   45    1.811495         (38.15, 23.55)
# 1        ACAMS09   54    2.173086         (37.85, 23.75)
# 2        ACAMS01   46    1.732642         (38.15, 23.65)
# 3        ACAMS10   55    2.227015         (37.85, 23.85)
# 4        ACAMS11   56    2.156552         (37.85, 23.95)
# ...          ...  ...         ...                    ...
# 1726459  GR0031A   15    1.239790       (37.932, 23.713)
# 1726460  GR0120A   21    1.341418       (37.901, 23.879)
# 1726461   PAN045   73    4.024065  (37.948063, 23.72836)
# 1726462   NTUA01  101    3.987019  (37.97721, 23.783016)
# 1726463  GR0027A    9    1.276996       (37.978, 23.727)
#
# [1726464 rows x 19 columns]

# %%
pm25_edges = [0, 12.0, 35.4, 55.4, 150.4, 250.4, np.inf]
pm25_labels = ["Good", "Moderate", "Unhealthy for SG", "Unhealthy", "Very Unhealthy", "Hazardous"]

# %%
pm10_edges = [0, 54, 154, 254, 354, 424, np.inf]
pm10_labels = ["Good", "Moderate", "Unhealthy for SG", "Unhealthy", "Very Unhealthy", "Hazardous"]

# %%
def add_pm_bins(df, col, edges, labels, out_col):
    if col in df.columns:
        df[out_col] = pd.cut(df[col], bins=edges, labels=labels, include_lowest=True)
        print(f"Created {out_col} from {col}")
    else:
        print(f"Skipped: column '{col}' not found.")

# %%
add_pm_bins(df_athens, 'PM2.5', pm25_edges, pm25_labels, 'PM25_AQI_bin')
add_pm_bins(df_athens, 'PM10', pm10_edges, pm10_labels, 'PM10_AQI_bin')
# Out:
# Created PM25_AQI_bin from PM2.5
# Created PM10_AQI_bin from PM10

# %%
df_athens
# Out:
#                        Date                             station_name  \
# 0       2020-05-01 00:00:00                    Athens CAMS station 0
# 1       2020-05-01 00:00:00                    Athens CAMS station 9
# 2       2020-05-01 00:00:00                    Athens CAMS station 1
# 3       2020-05-01 00:00:00                   Athens CAMS station 10
# 4       2020-05-01 00:00:00                   Athens CAMS station 11
# ...                     ...                                      ...
# 1726459 2023-05-29 23:00:00                                   SMYRNI
# 1726460 2023-05-29 23:00:00                                   KOROPI
# 1726461 2023-05-29 23:00:00                              PANACEA_045
# 1726462 2023-05-29 23:00:00  National Technical University of Athens
# 1726463 2023-05-29 23:00:00                                  ATHINAS
#
#          Wind-Speed (U)  Wind-Speed (V)  Dewpoint Temp  Soil Temp  \
# 0              1.713115       -0.588855      10.046454  17.083554
# 1              1.960498       -0.937417      10.270286  17.909675
# 2              1.640985       -0.556073       9.700422  16.976489
# 3              2.003834       -0.971722      10.159251  17.993456
# 4              1.954063       -0.912335       9.993532  17.957935
# ...                 ...             ...            ...        ...
# 1726459        0.240230       -1.216293      13.464139  20.926649
# 1726460        0.075186       -1.339309      13.110978  21.116500
# 1726461       -0.012447       -4.024046       0.817448  16.663882
# 1726462       -0.491393       -3.956621      12.422827  20.905300
# 1726463        0.209901       -1.259627      13.790172  21.719023
#
#          Total Percipitation  Vegitation (High)  Vegitation (Low)       Temp  \
# 0                   0.000035           1.699026          2.244626  12.948856
# 1                   0.000037           1.743299          1.431182  14.011539
# 2                   0.000040           1.642665          2.172998  12.550690
# 3                   0.000036           1.753648          1.582832  14.261641
# 4                   0.000036           1.706804          1.806660  14.179075
# ...                      ...                ...               ...        ...
# 1726459             0.000809           1.557783          1.392521  16.946201
# 1726460             0.000581           1.663799          2.290440  17.310772
# 1726461             0.000117           1.462879          1.247304  17.860900
# 1726462             0.000786           1.469335          0.926387  22.035118
# 1726463             0.000797           1.039985          1.013138  17.284556
#
#          ...       PM10      PM2.5        NO2         O3     code   id  \
# 0        ...   8.101824   6.200135   3.479941   76.28401  ACAMS00   45
# 1        ...  10.520411   7.836725  17.563843   74.39110  ACAMS09   54
# 2        ...   8.587352   6.306404   2.892315   74.56569  ACAMS01   46
# 3        ...  10.917974   8.207660  17.196804   67.90412  ACAMS10   55
# 4        ...  11.353168   8.217451  15.817172   67.63471  ACAMS11   56
# ...      ...        ...        ...        ...        ...      ...  ...
# 1726459  ...  19.000000  20.736000  24.000000   62.00000  GR0031A   15
# 1726460  ...  22.000000  12.737628  15.000000   58.00000  GR0120A   21
# 1726461  ...  20.490770  13.595480   9.606083  100.65001   PAN045   73
# 1726462  ...  14.873333  13.720000   5.000000   99.00000   NTUA01  101
# 1726463  ...  19.360000  18.053333  27.000000    9.00000  GR0027A    9
#
#          Wind_Speed                  Point PM25_AQI_bin PM10_AQI_bin
# 0          1.811495         (38.15, 23.55)         Good         Good
# 1          2.173086         (37.85, 23.75)         Good         Good
# 2          1.732642         (38.15, 23.65)         Good         Good
# 3          2.227015         (37.85, 23.85)         Good         Good
# 4          2.156552         (37.85, 23.95)         Good         Good
# ...             ...                    ...          ...          ...
# 1726459    1.239790       (37.932, 23.713)     Moderate         Good
# 1726460    1.341418       (37.901, 23.879)     Moderate         Good
# 1726461    4.024065  (37.948063, 23.72836)     Moderate         Good
# 1726462    3.987019  (37.97721, 23.783016)     Moderate         Good
# 1726463    1.276996       (37.978, 23.727)     Moderate         Good
#
# [1726464 rows x 21 columns]

# %%
df_athens["PM10_AQI_bin"].value_counts()
# Out:
# PM10_AQI_bin
# Good                1639604
# Moderate              83896
# Unhealthy for SG       2614
# Unhealthy               264
# Very Unhealthy           56
# Hazardous                30
# Name: count, dtype: int64

# %%
df_athens["PM25_AQI_bin"].value_counts()
# Out:
# PM25_AQI_bin
# Good                908327
# Moderate            731471
# Unhealthy for SG     63113
# Unhealthy            21568
# Very Unhealthy        1683
# Hazardous              302
# Name: count, dtype: int64

# %%
df_athens['Temperature_Binary'] = (df_athens['Temp'] > 15).astype(int)
df_athens
# Out:
#                        Date                             station_name  \
# 0       2020-05-01 00:00:00                    Athens CAMS station 0
# 1       2020-05-01 00:00:00                    Athens CAMS station 9
# 2       2020-05-01 00:00:00                    Athens CAMS station 1
# 3       2020-05-01 00:00:00                   Athens CAMS station 10
# 4       2020-05-01 00:00:00                   Athens CAMS station 11
# ...                     ...                                      ...
# 1726459 2023-05-29 23:00:00                                   SMYRNI
# 1726460 2023-05-29 23:00:00                                   KOROPI
# 1726461 2023-05-29 23:00:00                              PANACEA_045
# 1726462 2023-05-29 23:00:00  National Technical University of Athens
# 1726463 2023-05-29 23:00:00                                  ATHINAS
#
#          Wind-Speed (U)  Wind-Speed (V)  Dewpoint Temp  Soil Temp  \
# 0              1.713115       -0.588855      10.046454  17.083554
# 1              1.960498       -0.937417      10.270286  17.909675
# 2              1.640985       -0.556073       9.700422  16.976489
# 3              2.003834       -0.971722      10.159251  17.993456
# 4              1.954063       -0.912335       9.993532  17.957935
# ...                 ...             ...            ...        ...
# 1726459        0.240230       -1.216293      13.464139  20.926649
# 1726460        0.075186       -1.339309      13.110978  21.116500
# 1726461       -0.012447       -4.024046       0.817448  16.663882
# 1726462       -0.491393       -3.956621      12.422827  20.905300
# 1726463        0.209901       -1.259627      13.790172  21.719023
#
#          Total Percipitation  Vegitation (High)  Vegitation (Low)       Temp  \
# 0                   0.000035           1.699026          2.244626  12.948856
# 1                   0.000037           1.743299          1.431182  14.011539
# 2                   0.000040           1.642665          2.172998  12.550690
# 3                   0.000036           1.753648          1.582832  14.261641
# 4                   0.000036           1.706804          1.806660  14.179075
# ...                      ...                ...               ...        ...
# 1726459             0.000809           1.557783          1.392521  16.946201
# 1726460             0.000581           1.663799          2.290440  17.310772
# 1726461             0.000117           1.462879          1.247304  17.860900
# 1726462             0.000786           1.469335          0.926387  22.035118
# 1726463             0.000797           1.039985          1.013138  17.284556
#
#          ...      PM2.5        NO2         O3     code   id Wind_Speed  \
# 0        ...   6.200135   3.479941   76.28401  ACAMS00   45   1.811495
# 1        ...   7.836725  17.563843   74.39110  ACAMS09   54   2.173086
# 2        ...   6.306404   2.892315   74.56569  ACAMS01   46   1.732642
# 3        ...   8.207660  17.196804   67.90412  ACAMS10   55   2.227015
# 4        ...   8.217451  15.817172   67.63471  ACAMS11   56   2.156552
# ...      ...        ...        ...        ...      ...  ...        ...
# 1726459  ...  20.736000  24.000000   62.00000  GR0031A   15   1.239790
# 1726460  ...  12.737628  15.000000   58.00000  GR0120A   21   1.341418
# 1726461  ...  13.595480   9.606083  100.65001   PAN045   73   4.024065
# 1726462  ...  13.720000   5.000000   99.00000   NTUA01  101   3.987019
# 1726463  ...  18.053333  27.000000    9.00000  GR0027A    9   1.276996
#
#                          Point  PM25_AQI_bin PM10_AQI_bin Temperature_Binary
# 0               (38.15, 23.55)          Good         Good                  0
# 1               (37.85, 23.75)          Good         Good                  0
# 2               (38.15, 23.65)          Good         Good                  0
# 3               (37.85, 23.85)          Good         Good                  0
# 4               (37.85, 23.95)          Good         Good                  0
# ...                        ...           ...          ...                ...
# 1726459       (37.932, 23.713)      Moderate         Good                  1
# 1726460       (37.901, 23.879)      Moderate         Good                  1
# 1726461  (37.948063, 23.72836)      Moderate         Good                  1
# 1726462  (37.97721, 23.783016)      Moderate         Good                  1
# 1726463       (37.978, 23.727)      Moderate         Good                  1
#
# [1726464 rows x 22 columns]

# %%
df_athens["Temperature_Binary"].value_counts()
# Out:
# Temperature_Binary
# 1    981289
# 0    745175
# Name: count, dtype: int64

# %%
df_athens.to_csv('athens_results.csv')

# %%
from statsmodels.tsa.seasonal import STL

def robust_zscore(x):
    x = np.asarray(x)
    med = np.median(x)
    mad = np.median(np.abs(x - med))
    if mad == 0:
        std = np.std(x)
        return (x - med) / std if std != 0 else np.zeros_like(x)
    return (x - med) / (1.4826 * mad)

# %%
def safe_name(colname):
    return str(colname).replace('.', '_').replace(' ', '_').replace('-', '_')

# %%
def compute_zresids_stl(df,
                        dt_col='Date',
                        station_col='station_name',
                        vars_to_process=None,
                        period=24):

    if vars_to_process is None:
        vars_to_process = ['PM10', 'PM2.5', 'NO2', 'O3', 'Temp']

    df = df.copy()
    df[dt_col] = pd.to_datetime(df[dt_col])
    df = df.sort_values([station_col, dt_col])

    zframes = []

    for var in vars_to_process:
        if var not in df.columns:
            raise KeyError(f"Column '{var}' not found in dataframe")

        results = []
        for station, g in df.groupby(station_col, sort=False):
            s = g.set_index(dt_col)[var].astype(float)

            if len(s) < period * 2:
                # not enough data -> produce NaNs for zresid
                out = pd.DataFrame({'z_resid': [np.nan] * len(s)}, index=s.index)
            else:
                stl = STL(s, period=period, robust=True)
                res = stl.fit()
                resid = res.resid.values
                z = robust_zscore(resid)
                out = pd.DataFrame({'z_resid': z}, index=s.index)

            out = out.reset_index().rename(columns={dt_col: 'dt_index'})
            out[station_col] = station
            results.append(out)

        all_out = pd.concat(results, ignore_index=True).rename(columns={'dt_index': dt_col})
        colname = f"{safe_name(var)}_z_resid"
        all_out = all_out[[dt_col, station_col, 'z_resid']].rename(columns={'z_resid': colname})

        zframes.append(all_out)

    merged_z = None
    for zf in zframes:
        if merged_z is None:
            merged_z = zf
        else:
            merged_z = pd.merge(merged_z, zf, on=[dt_col, station_col], how='outer')

    df_out = pd.merge(df, merged_z, on=[dt_col, station_col], how='left')

    return df_out

# %%
def apply_thresholds(df_with_z,
                    vars_to_process=None,
                    z_thresh=None,
                    dt_col='Date'):

    df = df_with_z.copy()
    if vars_to_process is None:
        zcols = [c for c in df.columns if c.endswith('_z_resid')]
        vars_toprocess = [c[:-7].replace('', '.') for c in zcols]

    if isinstance(z_thresh, dict):
        thresh_map = z_thresh
    else:
        thresh_map = {v: z_thresh for v in vars_to_process}

    for var in vars_to_process:
        suf = safe_name(var)
        zcol = f"{suf}_z_resid"
        if zcol not in df.columns:
            raise KeyError(f"Expected z-resid column '{zcol}' not found. Run compute_zresids_stl first.")

        t = thresh_map.get(var, thresh_map.get(suf, None))
        if t is None:
            raise ValueError(f"No threshold specified for variable '{var}' (provide z_thresh numeric or dict).")

        two_col = f"{suf}_outlier_two_sided"
        pos_col = f"{suf}_outlier_positive_spike"

        df[two_col] = df[zcol].abs() > t
        df[pos_col] = df[zcol] > t

        df[two_col] = df[two_col].fillna(False)
        df[pos_col] = df[pos_col].fillna(False)

    return df

# %%
vars_to_do = ['PM10', 'PM2.5', 'NO2', 'O3']

df_z = compute_zresids_stl(
    df_athens,
    dt_col='Date',
    station_col='station_name',
    vars_to_process=vars_to_do,
    period=24
)


per_var_thresh = {
    'PM10': 15.0,
    'PM2.5': 12.0,
    'NO2': 10.0,
    'O3': 8.0
}

df_final = apply_thresholds(
    df_z,
    vars_to_process=vars_to_do,
    z_thresh=per_var_thresh
)

df_final
# Out:
#                        Date     station_name  Wind-Speed (U)  Wind-Speed (V)  \
# 0       2020-05-01 00:00:00     ARISTOTELOUS        1.945101       -1.013354
# 1       2020-05-01 01:00:00     ARISTOTELOUS        1.932266       -1.028591
# 2       2020-05-01 02:00:00     ARISTOTELOUS        1.952611       -1.090199
# 3       2020-05-01 03:00:00     ARISTOTELOUS        1.938605       -1.169774
# 4       2020-05-01 04:00:00     ARISTOTELOUS        1.750025       -1.219598
# ...                     ...              ...             ...             ...
# 1726459 2023-05-29 19:00:00  THRAKOMAKEDONES        0.146635       -1.387274
# 1726460 2023-05-29 20:00:00  THRAKOMAKEDONES        0.356107       -1.131180
# 1726461 2023-05-29 21:00:00  THRAKOMAKEDONES        0.476565       -1.106026
# 1726462 2023-05-29 22:00:00  THRAKOMAKEDONES        0.464936       -1.093732
# 1726463 2023-05-29 23:00:00  THRAKOMAKEDONES        0.419261       -1.060194
#
#          Dewpoint Temp  Soil Temp  Total Percipitation  Vegitation (High)  \
# 0            10.750844  18.336251             0.000041           0.946851
# 1            10.732582  18.073293             0.000000           0.946307
# 2            10.666181  17.808540             0.000000           0.946307
# 3            10.596040  17.542913             0.000000           0.946307
# 4            10.583603  17.284210             0.000000           0.946307
# ...                ...        ...                  ...                ...
# 1726459      11.444146  20.215399             0.000991           1.557540
# 1726460      12.277067  20.100394             0.000991           1.557540
# 1726461      12.598931  19.944619             0.000991           1.557540
# 1726462      12.556181  19.765762             0.000991           1.557540
# 1726463      12.557512  19.586577             0.000991           1.557540
#
#          Vegitation (Low)       Temp  ...  NO2_z_resid  O3_z_resid  \
# 0                0.961039  13.880884  ...     5.792260    0.009213
# 1                0.960796  13.311452  ...     0.949268   -0.162574
# 2                0.960796  12.885998  ...     0.901087   -0.115865
# 3                0.960796  12.533074  ...     1.631906   -0.005836
# 4                0.960796  12.331860  ...     0.086190    0.187277
# ...                   ...        ...  ...          ...         ...
# 1726459          2.018631  18.418121  ...    -0.405352   -0.099854
# 1726460          2.018631  17.496992  ...     0.465592   -0.009143
# 1726461          2.018631  16.513508  ...     0.050986    0.201776
# 1726462          2.018631  15.945738  ...    -0.045996    0.363963
# 1726463          2.018631  15.806421  ...     1.719166   -0.682572
#
#          PM10_outlier_two_sided  PM10_outlier_positive_spike  \
# 0                          True                         True
# 1                          True                         True
# 2                          True                         True
# 3                          True                         True
# 4                          True                         True
# ...                         ...                          ...
# 1726459                   False                        False
# 1726460                   False                        False
# 1726461                   False                        False
# 1726462                   False                        False
# 1726463                   False                        False
#
#          PM2_5_outlier_two_sided PM2_5_outlier_positive_spike  \
# 0                           True                         True
# 1                           True                         True
# 2                           True                         True
# 3                           True                         True
# 4                           True                         True
# ...                          ...                          ...
# 1726459                    False                        False
# 1726460                    False                        False
# 1726461                    False                        False
# 1726462                    False                        False
# 1726463                    False                        False
#
#          NO2_outlier_two_sided  NO2_outlier_positive_spike  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 1726459                  False                       False
# 1726460                  False                       False
# 1726461                  False                       False
# 1726462                  False                       False
# 1726463                  False                       False
#
#         O3_outlier_two_sided O3_outlier_positive_spike
# 0                      False                     False
# 1                      False                     False
# 2                      False                     False
# 3                      False                     False
# 4                      False                     False
# ...                      ...                       ...
# 1726459                False                     False
# 1726460                False                     False
# 1726461                False                     False
# 1726462                False                     False
# 1726463                False                     False
#
# [1726464 rows x 34 columns]

# %%
df_final['PM10_outlier_two_sided'].value_counts()
# Out:
# PM10_outlier_two_sided
# False    1702444
# True       24020
# Name: count, dtype: int64

# %%
df_final['PM2_5_outlier_two_sided'].value_counts()
# Out:
# PM2_5_outlier_two_sided
# False    1694054
# True       32410
# Name: count, dtype: int64

# %%
df_final['NO2_outlier_two_sided'].value_counts()
# Out:
# NO2_outlier_two_sided
# False    1658656
# True       67808
# Name: count, dtype: int64

# %%
df_final['O3_outlier_two_sided'].value_counts()
# Out:
# O3_outlier_two_sided
# False    1691338
# True       35126
# Name: count, dtype: int64

# %%
print(df_final[df_final['PM10_outlier_two_sided'] == True]["PM10"].mean())
print(df_final[df_final["PM10_outlier_two_sided"] == False]["PM10"].mean())
# Out:
# 91.56929405453097
# 21.51707847645878

# %%
print(df_final[df_final['PM2_5_outlier_two_sided'] == True]["PM2.5"].mean())
print(df_final[df_final["PM2_5_outlier_two_sided"] == False]["PM2.5"].mean())
# Out:
# 61.76921643509409
# 14.181396413999257

# %%
print(df_final[df_final['NO2_outlier_two_sided'] == True]["NO2"].mean())
print(df_final[df_final["NO2_outlier_two_sided"] == False]["NO2"].mean())
# Out:
# 40.57260459759763
# 20.319195665149145

# %%
print(df_final[df_final['O3_outlier_two_sided'] == True]["O3"].mean())
print(df_final[df_final["O3_outlier_two_sided"] == False]["O3"].mean())
# Out:
# 57.38938874427342
# 66.37644452521702

# %%
print(df_final[(df_final['station_name'] == "Athens CAMS station 14") & (df_final['PM2_5_outlier_two_sided'] == True)]["PM2.5"].mean())
print(df_final[(df_final['station_name'] == "ATH-ENVICARE-0") & (df_final['PM2_5_outlier_two_sided'] == True)]["PM2.5"].mean())
# Out:
# 25.901925637004407
# 135.11305036547355

# %%
df_cleaned = df_final.copy()

# %%
outlier_columns = ['PM10_outlier_two_sided', 'PM2_5_outlier_two_sided', 
                    'NO2_outlier_two_sided', 'O3_outlier_two_sided']

has_any_outlier = df_cleaned[outlier_columns].any(axis=1)

print(f"Original rows: {len(df_cleaned):,}")
print(f"Rows with ANY outlier: {has_any_outlier.sum():,}")
print(f"Clean rows (no outliers): {len(df_cleaned) - has_any_outlier.sum():,}")
# Out:
# Original rows: 1,726,464
# Rows with ANY outlier: 132,285
# Clean rows (no outliers): 1,594,179

# %%
df_no_outliers = df_cleaned[~has_any_outlier].copy()

# %%
print(f"\nCleaned dataframe rows: {len(df_no_outliers):,}")
print(f"Removed {has_any_outlier.sum():,} rows")
# Out:
# Cleaned dataframe rows: 1,594,179
# Removed 132,285 rows

# %%
df_no_outliers = df_no_outliers.drop(columns = ['PM10_z_resid', 'PM2_5_z_resid', 'NO2_z_resid', 'O3_z_resid', 'PM10_outlier_two_sided', 'PM10_outlier_positive_spike', 'PM2_5_outlier_two_sided', 'PM2_5_outlier_positive_spike', 'NO2_outlier_two_sided', 'NO2_outlier_positive_spike', 'O3_outlier_two_sided', 'O3_outlier_positive_spike'])

df_no_outliers = df_no_outliers.reset_index(drop=True)

# %%
df_no_outliers
# Out:
#                        Date     station_name  Wind-Speed (U)  Wind-Speed (V)  \
# 0       2020-05-01 05:00:00     ARISTOTELOUS        1.344296       -1.052719
# 1       2020-05-01 06:00:00     ARISTOTELOUS        1.483873       -1.015284
# 2       2020-05-01 07:00:00     ARISTOTELOUS        2.098160       -0.621335
# 3       2020-05-01 09:00:00     ARISTOTELOUS        2.380353        0.293706
# 4       2020-05-01 10:00:00     ARISTOTELOUS        2.558784        0.829467
# ...                     ...              ...             ...             ...
# 1594174 2023-05-29 19:00:00  THRAKOMAKEDONES        0.146635       -1.387274
# 1594175 2023-05-29 20:00:00  THRAKOMAKEDONES        0.356107       -1.131180
# 1594176 2023-05-29 21:00:00  THRAKOMAKEDONES        0.476565       -1.106026
# 1594177 2023-05-29 22:00:00  THRAKOMAKEDONES        0.464936       -1.093732
# 1594178 2023-05-29 23:00:00  THRAKOMAKEDONES        0.419261       -1.060194
#
#          Dewpoint Temp  Soil Temp  Total Percipitation  Vegitation (High)  \
# 0            11.516724  17.099011             0.000000           0.946307
# 1            11.186682  17.059156             0.000000           0.946307
# 2            10.746824  17.154367             0.000000           0.946307
# 3             9.423704  17.676638             0.000004           0.946307
# 4             8.731026  18.044265             0.000005           0.946307
# ...                ...        ...                  ...                ...
# 1594174      11.444146  20.215399             0.000991           1.557540
# 1594175      12.277067  20.100394             0.000991           1.557540
# 1594176      12.598931  19.944619             0.000991           1.557540
# 1594177      12.556181  19.765762             0.000991           1.557540
# 1594178      12.557512  19.586577             0.000991           1.557540
#
#          Vegitation (Low)       Temp  ...  PM2.5   NO2    O3     code  id  \
# 0                0.960796  13.980085  ...   31.0  47.0   2.0  GR0003A  10
# 1                0.960796  16.919566  ...   43.0  45.0   2.0  GR0003A  10
# 2                0.960796  19.077879  ...   27.0  51.0   2.0  GR0003A  10
# 3                0.960796  22.152517  ...   36.0  46.0   3.0  GR0003A  10
# 4                0.960796  23.172478  ...   27.0  37.0   6.0  GR0003A  10
# ...                   ...        ...  ...    ...   ...   ...      ...  ..
# 1594174          2.018631  18.418121  ...   10.0   1.0  90.0  GR0037A  18
# 1594175          2.018631  17.496992  ...   14.0   3.0  89.0  GR0037A  18
# 1594176          2.018631  16.513508  ...   12.0   1.0  95.0  GR0037A  18
# 1594177          2.018631  15.945738  ...   18.0   2.0  94.0  GR0037A  18
# 1594178          2.018631  15.806421  ...    7.0   6.0  84.0  GR0037A  18
#
#         Wind_Speed             Point      PM25_AQI_bin PM10_AQI_bin  \
# 0         1.707440  (37.988, 23.728)          Moderate     Moderate
# 1         1.797966  (37.988, 23.728)  Unhealthy for SG     Moderate
# 2         2.188226  (37.988, 23.728)          Moderate     Moderate
# 3         2.398405  (37.988, 23.728)  Unhealthy for SG     Moderate
# 4         2.689868  (37.988, 23.728)          Moderate     Moderate
# ...            ...               ...               ...          ...
# 1594174   1.395002  (38.144, 23.758)              Good         Good
# 1594175   1.185909  (38.144, 23.758)          Moderate         Good
# 1594176   1.204329  (38.144, 23.758)              Good         Good
# 1594177   1.188450  (38.144, 23.758)          Moderate         Good
# 1594178   1.140084  (38.144, 23.758)              Good         Good
#
#         Temperature_Binary
# 0                        0
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 1594174                  1
# 1594175                  1
# 1594176                  1
# 1594177                  1
# 1594178                  1
#
# [1594179 rows x 22 columns]

# %%
import matplotlib.pyplot as plt

def plot_station_outliers(station_name, df_final):
    station_df = df_final[df_final['station_name'] == station_name].sort_values('Date')

    fig, axes = plt.subplots(4, 3, figsize=(15, 12))
    axes = axes.flatten()

    for idx, var in enumerate(['PM10', 'PM2.5', 'NO2', 'O3']):
        suf = safe_name(var)
        zcol = f'{suf}_z_resid'
        outlier_col = f'{suf}_outlier_two_sided'

        axes[idx*3].plot(station_df['Date'], station_df[var], alpha=0.5, label='original')
        outliers = station_df[station_df[outlier_col]]
        axes[idx*3].scatter(outliers['Date'], outliers[var], color='red', s=10, label='outlier')
        axes[idx*3].set_title(f'{var} – {station_name}')
        axes[idx*3].legend()

        axes[idx*3+1].plot(station_df['Date'], station_df[zcol], alpha=0.5)
        axes[idx*3+1].axhline(y=per_var_thresh[var], color='r', linestyle='--',
                                label=f'Threshold: {per_var_thresh[var]}')
        axes[idx*3+1].axhline(y=-per_var_thresh[var], color='r', linestyle='--')
        axes[idx*3+1].set_title(f'{var} Z-Residuals')

        axes[idx*3+2].hist(station_df[zcol].dropna(), bins=50, edgecolor='black')
        axes[idx*3+2].axvline(x=per_var_thresh[var], color='r', linestyle='--')
        axes[idx*3+2].axvline(x=-per_var_thresh[var], color='r', linestyle='--')
        axes[idx*3+2].set_title(f'{var} Z-Residual Distribution')

# %%
plot_station_outliers('ARISTOTELOUS', df_final)
